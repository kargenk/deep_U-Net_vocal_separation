# %%
#!usr/bin/env python3
# -*- coding: utf-8 -*-

# %%
from librosa.core import load, resample, stft, istft
from librosa.output import write_wav
from librosa.util import find_files
import numpy as np
import const_for_colab as C
import util_for_colab as util
import yaml
import os

# %% [markdown]
# ## 周辺知識
# - **パラデータ** ... 各トラック単体のデータ
# - **ステムデータ** ... 複数のトラックをまとめたもの(パラデータの集合)である．
#
# MedleyDBのデータセットには生音源と，各種のステム音源があり，Metadataのyamlファイルにそれぞれの情報が記載されている．
# vocalが入っているのは，instrumentalの属性値が'male singer'，'female singer'，'vocalists'のものである．複数ある場合もあれば，どれか一つのみの場合もあるので各々でマッチさせる必要がある．

# %%
PATH_MEDLEYDB = 'E:\Datasets\sound\MedleyDB\V1'
PATH_E_DRIVE = 'E:/Datasets/sound/MedleyDB_gen/'

metadata_list = find_files(PATH_MEDLEYDB.rstrip('\V1'), ext='yaml')
print(metadata_list[:5])
# Out:
# ['E:\\Datasets\\sound\\MedleyDB\\Metadata\\AClassicEducation_NightOwl_METADATA.yaml', 'E:\\Datasets\\sound\\MedleyDB\\Metadata\\AimeeNorwich_Child_METADATA.yaml', 'E:\\Datasets\\sound\\MedleyDB\\Metadata\\AimeeNorwich_Flying_METADATA.yaml', 'E:\\Datasets\\sound\\MedleyDB\\Metadata\\AlexanderRoss_GoodbyeBolero_METADATA.yaml', 'E:\\Datasets\\sound\\MedleyDB\\Metadata\\AlexanderRoss_VelvetCurtain_METADATA.yaml']

# %%
def save_medleydb_mix(y_mixture, file_name):
    mix_spec = np.abs(
                    stft(y_mixture, n_fft=C.FFT_SIZE, hop_length=C.HOP_LENGTH))\
                .astype(np.float32)
    
    phase = np.exp(1.j*np.angle(mix_spec))
    y_mix = istft(mix_spec*phase,
                  hop_length=C.HOP_LENGTH, win_length=C.FFT_SIZE)
    
    write_wav(PATH_E_DRIVE + file_name + '_mix.wav', y_mix, C.SAMPLING_RATE)
    print('Saving: ' + PATH_E_DRIVE + file_name + '_mix.wav')

def save_medleydb_inst(y_instrument, file_name):
    inst_spec = np.abs(
                    stft(y_instrument, n_fft=C.FFT_SIZE, hop_length=C.HOP_LENGTH))\
                .astype(np.float32)
    phase = np.exp(1.j*np.angle(inst_spec))
    y_inst = istft(inst_spec*phase,
                   hop_length=C.HOP_LENGTH, win_length=C.FFT_SIZE)
    write_wav(PATH_E_DRIVE + file_name + '_inst.wav', y_inst, C.SAMPLING_RATE)
    print('Saving: ' + PATH_E_DRIVE + file_name + '_inst.wav')

def save_medleydb_vocal(y_vocal, file_name):
    vocal_spec = np.abs(
                    stft(y_vocal, n_fft=C.FFT_SIZE, hop_length=C.HOP_LENGTH))\
                .astype(np.float32)
    phase = np.exp(1.j*np.angle(vocal_spec))
    y_vocal = istft(vocal_spec*phase,
                    hop_length=C.HOP_LENGTH, win_length=C.FFT_SIZE)
    write_wav(PATH_E_DRIVE + file_name + '_vocal.wav', y_vocal, C.SAMPLING_RATE)
    print('Saving: ' + PATH_E_DRIVE + file_name + '_vocal.wav')

# %%
for metafile in metadata_list:
    print('YAML file: %s' % metafile)
    
    # 曲名を抽出(末尾の'_METADATA.yaml'を除いた文字列を格納)
    songname = metafile.split('\\')[-1][:-14]
    print('song: %s' % songname)
    
    # yamlファイルの読み込み
    with open(metafile, mode='r') as f:
        data = yaml.load(f)
    
    # インストがあるものはスキップ
    if data['instrumental'] != 'no':
        print('Instrumental track. Skipped.')
        continue
    
    stem_vocal = []
    stem_inst = []
    stem_path = os.path.join(PATH_MEDLEYDB, songname, data['stem_dir'])
    mix_filename = data["mix_filename"]
    
    # stemデータの抽出
    for s in data['stems']:
        stem = data['stems'][s]
        file_name = stem['filename']
        
        # 各ステムファイルのcomponent:構成要素とinstrument:楽器を表示
        print('stem: %s %s %s' % (file_name, stem['component'], stem['instrument']))
        
        # instrumentの属性値がボーカルのものと楽器のものを分ける
        if 'male' in stem['instrument'] or \
            'singer' in stem['instrument'] or \
            'vocalists' in stem['instrument']:
                stem_vocal.append(file_name)
                print('this is vocal!')
        else:
            stem_inst.append(file_name)
        
    print('detexted vocals:')
    print(stem_vocal)
    
    # ボーカルもインストもないものはスキップ
    if (len(stem_vocal) == 0) or (len(stem_inst) == 0):
        print('empty vocal or inst data ... skip!')
        continue
    
    # 各音源をまとめる
    audio_inst = sum([load(os.path.join(stem_path, f), sr=None, mono=True)[0]
                      for f in stem_inst])
    audio_vocal = sum([load(os.path.join(stem_path, f), sr=None, mono=True)[0]
                      for f in stem_vocal])
#     audio_mix = audio_inst + audio_vocal
    audio_mix, _ = load(os.path.join(PATH_MEDLEYDB, songname, mix_filename),
                            sr=None, mono=True)
    
#     # 各音源を保存
#     # リサンプリング
#     audio_mix = resample(audio_mix, 44100, C.SAMPLING_RATE)
#     audio_inst = resample(audio_inst, 44100, C.SAMPLING_RATE)
#     audio_vocal = resample(audio_vocal, 44100, C.SAMPLING_RATE)
#     save_medleydb_mix(audio_mix, songname)
#     save_medleydb_inst(audio_inst, songname)
#     save_medleydb_vocal(audio_vocal, songname)
    
    # スペクトログラムを保存
    util.save_spectrogram(audio_mix, audio_inst, audio_vocal, songname)
    
    print('*' * 150)
# Out:
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\AClassicEducation_NightOwl_METADATA.yaml
# song: AClassicEducation_NightOwl
# stem: AClassicEducation_NightOwl_STEM_11.wav  tambourine
# stem: AClassicEducation_NightOwl_STEM_13.wav melody male singer
# this is vocal!
# stem: AClassicEducation_NightOwl_STEM_09.wav  synthesizer
# stem: AClassicEducation_NightOwl_STEM_07.wav  distorted electric guitar
# stem: AClassicEducation_NightOwl_STEM_08.wav melody male singer
# this is vocal!
# stem: AClassicEducation_NightOwl_STEM_04.wav melody distorted electric guitar
# stem: AClassicEducation_NightOwl_STEM_03.wav  distorted electric guitar
# stem: AClassicEducation_NightOwl_STEM_02.wav  drum set
# stem: AClassicEducation_NightOwl_STEM_06.wav  distorted electric guitar
# stem: AClassicEducation_NightOwl_STEM_10.wav  vocalists
# this is vocal!
# stem: AClassicEducation_NightOwl_STEM_01.wav bass electric bass
# stem: AClassicEducation_NightOwl_STEM_12.wav  fx/processed sound
# stem: AClassicEducation_NightOwl_STEM_05.wav  clean electric guitar
# detexted vocals:
# ['AClassicEducation_NightOwl_STEM_13.wav', 'AClassicEducation_NightOwl_STEM_08.wav', 'AClassicEducation_NightOwl_STEM_10.wav']
# (513, 9845)
# (513, 9845)
# (513, 9845)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/AClassicEducation_NightOwl.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\AimeeNorwich_Child_METADATA.yaml
# song: AimeeNorwich_Child
# stem: AimeeNorwich_Child_STEM_01.wav  drum set
# stem: AimeeNorwich_Child_STEM_07.wav  acoustic guitar
# stem: AimeeNorwich_Child_STEM_04.wav melody female singer
# this is vocal!
# stem: AimeeNorwich_Child_STEM_03.wav  clean electric guitar
# stem: AimeeNorwich_Child_STEM_02.wav bass electric bass
# stem: AimeeNorwich_Child_STEM_06.wav  piano
# stem: AimeeNorwich_Child_STEM_05.wav  vocalists
# this is vocal!
# detexted vocals:
# ['AimeeNorwich_Child_STEM_04.wav', 'AimeeNorwich_Child_STEM_05.wav']
# (513, 64)
# (513, 10869)
# (513, 10869)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/AimeeNorwich_Child.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\AimeeNorwich_Flying_METADATA.yaml
# song: AimeeNorwich_Flying
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\AlexanderRoss_GoodbyeBolero_METADATA.yaml
# song: AlexanderRoss_GoodbyeBolero
# stem: AlexanderRoss_GoodbyeBolero_STEM_09.wav melody harmonica
# stem: AlexanderRoss_GoodbyeBolero_STEM_07.wav melody brass section
# stem: AlexanderRoss_GoodbyeBolero_STEM_08.wav melody viola section
# stem: AlexanderRoss_GoodbyeBolero_STEM_04.wav bass electric bass
# stem: AlexanderRoss_GoodbyeBolero_STEM_03.wav melody clean electric guitar
# stem: AlexanderRoss_GoodbyeBolero_STEM_02.wav  clean electric guitar
# stem: AlexanderRoss_GoodbyeBolero_STEM_06.wav melody male singer
# this is vocal!
# stem: AlexanderRoss_GoodbyeBolero_STEM_01.wav  acoustic guitar
# stem: AlexanderRoss_GoodbyeBolero_STEM_05.wav  drum set
# detexted vocals:
# ['AlexanderRoss_GoodbyeBolero_STEM_06.wav']
# (513, 24050)
# (513, 24050)
# (513, 24050)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/AlexanderRoss_GoodbyeBolero.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\AlexanderRoss_VelvetCurtain_METADATA.yaml
# song: AlexanderRoss_VelvetCurtain
# stem: AlexanderRoss_VelvetCurtain_STEM_09.wav  vocalists
# this is vocal!
# stem: AlexanderRoss_VelvetCurtain_STEM_07.wav melody brass section
# stem: AlexanderRoss_VelvetCurtain_STEM_08.wav melody string section
# stem: AlexanderRoss_VelvetCurtain_STEM_04.wav bass electric bass
# stem: AlexanderRoss_VelvetCurtain_STEM_03.wav  clean electric guitar
# stem: AlexanderRoss_VelvetCurtain_STEM_02.wav  clean electric guitar
# stem: AlexanderRoss_VelvetCurtain_STEM_06.wav melody male singer
# this is vocal!
# stem: AlexanderRoss_VelvetCurtain_STEM_10.wav  clean electric guitar
# stem: AlexanderRoss_VelvetCurtain_STEM_01.wav melody acoustic guitar
# stem: AlexanderRoss_VelvetCurtain_STEM_05.wav  drum set
# detexted vocals:
# ['AlexanderRoss_VelvetCurtain_STEM_09.wav', 'AlexanderRoss_VelvetCurtain_STEM_06.wav']
# (513, 29543)
# (513, 29543)
# (513, 29543)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/AlexanderRoss_VelvetCurtain.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\AmarLal_Rest_METADATA.yaml
# song: AmarLal_Rest
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\AmarLal_SpringDay1_METADATA.yaml
# song: AmarLal_SpringDay1
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\Auctioneer_OurFutureFaces_METADATA.yaml
# song: Auctioneer_OurFutureFaces
# stem: Auctioneer_OurFutureFaces_STEM_09.wav  auxiliary percussion
# stem: Auctioneer_OurFutureFaces_STEM_07.wav  vibraphone
# stem: Auctioneer_OurFutureFaces_STEM_08.wav melody male singer
# this is vocal!
# stem: Auctioneer_OurFutureFaces_STEM_04.wav  drum set
# stem: Auctioneer_OurFutureFaces_STEM_03.wav  vocalists
# this is vocal!
# stem: Auctioneer_OurFutureFaces_STEM_02.wav bass electric bass
# stem: Auctioneer_OurFutureFaces_STEM_06.wav melody horn section
# stem: Auctioneer_OurFutureFaces_STEM_10.wav  piano
# stem: Auctioneer_OurFutureFaces_STEM_01.wav  banjo
# stem: Auctioneer_OurFutureFaces_STEM_05.wav  clean electric guitar
# detexted vocals:
# ['Auctioneer_OurFutureFaces_STEM_08.wav', 'Auctioneer_OurFutureFaces_STEM_03.wav']
# (513, 11938)
# (513, 11938)
# (513, 11938)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/Auctioneer_OurFutureFaces.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\AvaLuna_Waterduct_METADATA.yaml
# song: AvaLuna_Waterduct
# stem: AvaLuna_Waterduct_STEM_07.wav  vibraphone
# stem: AvaLuna_Waterduct_STEM_08.wav melody male singer
# this is vocal!
# stem: AvaLuna_Waterduct_STEM_04.wav  drum set
# stem: AvaLuna_Waterduct_STEM_03.wav  vocalists
# this is vocal!
# stem: AvaLuna_Waterduct_STEM_02.wav  synthesizer
# stem: AvaLuna_Waterduct_STEM_06.wav  fx/processed sound
# stem: AvaLuna_Waterduct_STEM_01.wav bass electric bass
# stem: AvaLuna_Waterduct_STEM_05.wav  distorted electric guitar
# detexted vocals:
# ['AvaLuna_Waterduct_STEM_08.wav', 'AvaLuna_Waterduct_STEM_03.wav']
# (513, 14890)
# (513, 14890)
# (513, 14890)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/AvaLuna_Waterduct.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\BigTroubles_Phantom_METADATA.yaml
# song: BigTroubles_Phantom
# stem: BigTroubles_Phantom_STEM_01.wav bass electric bass
# stem: BigTroubles_Phantom_STEM_07.wav  distorted electric guitar
# stem: BigTroubles_Phantom_STEM_04.wav melody male singer
# this is vocal!
# stem: BigTroubles_Phantom_STEM_03.wav melody distorted electric guitar
# stem: BigTroubles_Phantom_STEM_02.wav  drum set
# stem: BigTroubles_Phantom_STEM_06.wav  male singer
# this is vocal!
# stem: BigTroubles_Phantom_STEM_05.wav melody distorted electric guitar
# detexted vocals:
# ['BigTroubles_Phantom_STEM_04.wav', 'BigTroubles_Phantom_STEM_06.wav']
# (513, 8438)
# (513, 8438)
# (513, 8438)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/BigTroubles_Phantom.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\BrandonWebster_DontHearAThing_METADATA.yaml
# song: BrandonWebster_DontHearAThing
# stem: BrandonWebster_DontHearAThing_STEM_03.wav  piano
# stem: BrandonWebster_DontHearAThing_STEM_02.wav melody female singer
# this is vocal!
# stem: BrandonWebster_DontHearAThing_STEM_01.wav  male speaker
# this is vocal!
# detexted vocals:
# ['BrandonWebster_DontHearAThing_STEM_02.wav', 'BrandonWebster_DontHearAThing_STEM_01.wav']
# (513, 9857)
# (513, 9857)
# (513, 9857)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/BrandonWebster_DontHearAThing.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\BrandonWebster_YesSirICanFly_METADATA.yaml
# song: BrandonWebster_YesSirICanFly
# stem: BrandonWebster_YesSirICanFly_STEM_02.wav melody male singer
# this is vocal!
# stem: BrandonWebster_YesSirICanFly_STEM_01.wav  piano
# detexted vocals:
# ['BrandonWebster_YesSirICanFly_STEM_02.wav']
# (513, 5722)
# (513, 5722)
# (513, 5722)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/BrandonWebster_YesSirICanFly.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\CelestialShore_DieForUs_METADATA.yaml
# song: CelestialShore_DieForUs
# stem: CelestialShore_DieForUs_STEM_09.wav  synthesizer
# stem: CelestialShore_DieForUs_STEM_07.wav melody tack piano
# stem: CelestialShore_DieForUs_STEM_08.wav melody clean electric guitar
# stem: CelestialShore_DieForUs_STEM_04.wav melody synthesizer
# stem: CelestialShore_DieForUs_STEM_03.wav bass electric bass
# stem: CelestialShore_DieForUs_STEM_02.wav melody female singer
# this is vocal!
# stem: CelestialShore_DieForUs_STEM_06.wav  drum set
# stem: CelestialShore_DieForUs_STEM_01.wav melody male singer
# this is vocal!
# stem: CelestialShore_DieForUs_STEM_05.wav  clean electric guitar
# detexted vocals:
# ['CelestialShore_DieForUs_STEM_02.wav', 'CelestialShore_DieForUs_STEM_01.wav']
# (513, 16002)
# (513, 16002)
# (513, 16002)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/CelestialShore_DieForUs.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\ChrisJacoby_BoothShotLincoln_METADATA.yaml
# song: ChrisJacoby_BoothShotLincoln
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\ChrisJacoby_PigsFoot_METADATA.yaml
# song: ChrisJacoby_PigsFoot
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\ClaraBerryAndWooldog_AirTraffic_METADATA.yaml
# song: ClaraBerryAndWooldog_AirTraffic
# stem: ClaraBerryAndWooldog_AirTraffic_STEM_07.wav  female singer
# this is vocal!
# stem: ClaraBerryAndWooldog_AirTraffic_STEM_08.wav melody female singer
# this is vocal!
# stem: ClaraBerryAndWooldog_AirTraffic_STEM_04.wav melody clean electric guitar
# stem: ClaraBerryAndWooldog_AirTraffic_STEM_03.wav bass electric bass
# stem: ClaraBerryAndWooldog_AirTraffic_STEM_02.wav  timpani
# stem: ClaraBerryAndWooldog_AirTraffic_STEM_06.wav  piano
# stem: ClaraBerryAndWooldog_AirTraffic_STEM_01.wav  drum set
# stem: ClaraBerryAndWooldog_AirTraffic_STEM_05.wav  lap steel guitar
# detexted vocals:
# ['ClaraBerryAndWooldog_AirTraffic_STEM_07.wav', 'ClaraBerryAndWooldog_AirTraffic_STEM_08.wav']
# (513, 9960)
# (513, 9960)
# (513, 9960)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/ClaraBerryAndWooldog_AirTraffic.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\ClaraBerryAndWooldog_Boys_METADATA.yaml
# song: ClaraBerryAndWooldog_Boys
# stem: ClaraBerryAndWooldog_Boys_STEM_09.wav  tack piano
# stem: ClaraBerryAndWooldog_Boys_STEM_07.wav  vocalists
# this is vocal!
# stem: ClaraBerryAndWooldog_Boys_STEM_08.wav melody tenor saxophone
# stem: ClaraBerryAndWooldog_Boys_STEM_04.wav  timpani
# stem: ClaraBerryAndWooldog_Boys_STEM_03.wav  brass section
# stem: ClaraBerryAndWooldog_Boys_STEM_02.wav  snare drum
# stem: ClaraBerryAndWooldog_Boys_STEM_06.wav melody female singer
# this is vocal!
# stem: ClaraBerryAndWooldog_Boys_STEM_01.wav  drum set
# stem: ClaraBerryAndWooldog_Boys_STEM_05.wav melody piano
# detexted vocals:
# ['ClaraBerryAndWooldog_Boys_STEM_07.wav', 'ClaraBerryAndWooldog_Boys_STEM_06.wav']
# (513, 8813)
# (513, 8813)
# (513, 8813)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/ClaraBerryAndWooldog_Boys.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\ClaraBerryAndWooldog_Stella_METADATA.yaml
# song: ClaraBerryAndWooldog_Stella
# stem: ClaraBerryAndWooldog_Stella_STEM_07.wav melody female singer
# this is vocal!
# stem: ClaraBerryAndWooldog_Stella_STEM_08.wav  vocalists
# this is vocal!
# stem: ClaraBerryAndWooldog_Stella_STEM_04.wav bass electric bass
# stem: ClaraBerryAndWooldog_Stella_STEM_03.wav  vibraphone
# stem: ClaraBerryAndWooldog_Stella_STEM_02.wav  auxiliary percussion
# stem: ClaraBerryAndWooldog_Stella_STEM_06.wav  synthesizer
# stem: ClaraBerryAndWooldog_Stella_STEM_01.wav  drum set
# stem: ClaraBerryAndWooldog_Stella_STEM_05.wav  piano
# detexted vocals:
# ['ClaraBerryAndWooldog_Stella_STEM_07.wav', 'ClaraBerryAndWooldog_Stella_STEM_08.wav']
# (513, 11240)
# (513, 11240)
# (513, 11240)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/ClaraBerryAndWooldog_Stella.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\ClaraBerryAndWooldog_TheBadGuys_METADATA.yaml
# song: ClaraBerryAndWooldog_TheBadGuys
# stem: ClaraBerryAndWooldog_TheBadGuys_STEM_02.wav melody female singer
# this is vocal!
# stem: ClaraBerryAndWooldog_TheBadGuys_STEM_01.wav  piano
# detexted vocals:
# ['ClaraBerryAndWooldog_TheBadGuys_STEM_02.wav']
# (513, 14625)
# (513, 14625)
# (513, 14625)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/ClaraBerryAndWooldog_TheBadGuys.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\ClaraBerryAndWooldog_WaltzForMyVictims_METADATA.yaml
# song: ClaraBerryAndWooldog_WaltzForMyVictims
# stem: ClaraBerryAndWooldog_WaltzForMyVictims_STEM_04.wav melody glockenspiel
# stem: ClaraBerryAndWooldog_WaltzForMyVictims_STEM_03.wav melody piano
# stem: ClaraBerryAndWooldog_WaltzForMyVictims_STEM_02.wav bass electric bass
# stem: ClaraBerryAndWooldog_WaltzForMyVictims_STEM_01.wav  drum set
# stem: ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05.wav melody female singer
# this is vocal!
# detexted vocals:
# ['ClaraBerryAndWooldog_WaltzForMyVictims_STEM_05.wav']
# (513, 10074)
# (513, 10074)
# (513, 10074)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/ClaraBerryAndWooldog_WaltzForMyVictims.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\Creepoid_OldTree_METADATA.yaml
# song: Creepoid_OldTree
# stem: Creepoid_OldTree_STEM_09.wav  male singer
# this is vocal!
# stem: Creepoid_OldTree_STEM_07.wav melody male singer
# this is vocal!
# stem: Creepoid_OldTree_STEM_08.wav melody male singer
# this is vocal!
# stem: Creepoid_OldTree_STEM_04.wav  drum set
# stem: Creepoid_OldTree_STEM_03.wav  fx/processed sound
# stem: Creepoid_OldTree_STEM_02.wav bass electric bass
# stem: Creepoid_OldTree_STEM_06.wav melody distorted electric guitar
# stem: Creepoid_OldTree_STEM_10.wav  auxiliary percussion
# stem: Creepoid_OldTree_STEM_01.wav melody vocalists
# this is vocal!
# stem: Creepoid_OldTree_STEM_05.wav  distorted electric guitar
# detexted vocals:
# ['Creepoid_OldTree_STEM_09.wav', 'Creepoid_OldTree_STEM_07.wav', 'Creepoid_OldTree_STEM_08.wav', 'Creepoid_OldTree_STEM_01.wav']
# (513, 17354)
# (513, 17354)
# (513, 17354)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/Creepoid_OldTree.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\CroqueMadame_Oil_METADATA.yaml
# song: CroqueMadame_Oil
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\CroqueMadame_Pilot_METADATA.yaml
# song: CroqueMadame_Pilot
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\Debussy_LenfantProdigue_METADATA.yaml
# song: Debussy_LenfantProdigue
# stem: Debussy_LenfantProdigue_STEM_02.wav melody piano
# stem: Debussy_LenfantProdigue_STEM_01.wav melody male singer
# this is vocal!
# detexted vocals:
# ['Debussy_LenfantProdigue_STEM_01.wav']
# (513, 12836)
# (513, 12836)
# (513, 12836)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/Debussy_LenfantProdigue.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\DreamersOfTheGhetto_HeavyLove_METADATA.yaml
# song: DreamersOfTheGhetto_HeavyLove
# stem: DreamersOfTheGhetto_HeavyLove_STEM_09.wav  synthesizer
# stem: DreamersOfTheGhetto_HeavyLove_STEM_07.wav  synthesizer
# stem: DreamersOfTheGhetto_HeavyLove_STEM_08.wav  female singer
# this is vocal!
# stem: DreamersOfTheGhetto_HeavyLove_STEM_04.wav  auxiliary percussion
# stem: DreamersOfTheGhetto_HeavyLove_STEM_03.wav  fx/processed sound
# stem: DreamersOfTheGhetto_HeavyLove_STEM_02.wav  vocalists
# this is vocal!
# stem: DreamersOfTheGhetto_HeavyLove_STEM_06.wav melody male singer
# this is vocal!
# stem: DreamersOfTheGhetto_HeavyLove_STEM_01.wav bass electric bass
# stem: DreamersOfTheGhetto_HeavyLove_STEM_05.wav  drum set
# detexted vocals:
# ['DreamersOfTheGhetto_HeavyLove_STEM_08.wav', 'DreamersOfTheGhetto_HeavyLove_STEM_02.wav', 'DreamersOfTheGhetto_HeavyLove_STEM_06.wav']
# (513, 16939)
# (513, 16939)
# (513, 16939)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/DreamersOfTheGhetto_HeavyLove.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\EthanHein_1930sSynthAndUprightBass_METADATA.yaml
# song: EthanHein_1930sSynthAndUprightBass
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\EthanHein_BluesForNofi_METADATA.yaml
# song: EthanHein_BluesForNofi
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\EthanHein_GirlOnABridge_METADATA.yaml
# song: EthanHein_GirlOnABridge
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\EthanHein_HarmonicaFigure_METADATA.yaml
# song: EthanHein_HarmonicaFigure
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\FacesOnFilm_WaitingForGa_METADATA.yaml
# song: FacesOnFilm_WaitingForGa
# stem: FacesOnFilm_WaitingForGa_STEM_11.wav  auxiliary percussion
# stem: FacesOnFilm_WaitingForGa_STEM_09.wav  vocalists
# this is vocal!
# stem: FacesOnFilm_WaitingForGa_STEM_07.wav  synthesizer
# stem: FacesOnFilm_WaitingForGa_STEM_08.wav  vibraphone
# stem: FacesOnFilm_WaitingForGa_STEM_04.wav  drum set
# stem: FacesOnFilm_WaitingForGa_STEM_03.wav melody male singer
# this is vocal!
# stem: FacesOnFilm_WaitingForGa_STEM_02.wav bass electric bass
# stem: FacesOnFilm_WaitingForGa_STEM_06.wav  distorted electric guitar
# stem: FacesOnFilm_WaitingForGa_STEM_10.wav melody vocalists
# this is vocal!
# stem: FacesOnFilm_WaitingForGa_STEM_01.wav  acoustic guitar
# stem: FacesOnFilm_WaitingForGa_STEM_05.wav  clean electric guitar
# detexted vocals:
# ['FacesOnFilm_WaitingForGa_STEM_09.wav', 'FacesOnFilm_WaitingForGa_STEM_03.wav', 'FacesOnFilm_WaitingForGa_STEM_10.wav']
# (513, 14794)
# (513, 14794)
# (513, 14794)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/FacesOnFilm_WaitingForGa.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\FamilyBand_Again_METADATA.yaml
# song: FamilyBand_Again
# stem: FamilyBand_Again_STEM_11.wav  auxiliary percussion
# stem: FamilyBand_Again_STEM_09.wav melody female singer
# this is vocal!
# stem: FamilyBand_Again_STEM_07.wav  lap steel guitar
# stem: FamilyBand_Again_STEM_08.wav  lap steel guitar
# stem: FamilyBand_Again_STEM_04.wav  acoustic guitar
# stem: FamilyBand_Again_STEM_03.wav  drum set
# stem: FamilyBand_Again_STEM_02.wav  vocalists
# this is vocal!
# stem: FamilyBand_Again_STEM_06.wav  distorted electric guitar
# stem: FamilyBand_Again_STEM_10.wav  melodica
# stem: FamilyBand_Again_STEM_01.wav bass electric bass
# stem: FamilyBand_Again_STEM_05.wav  clean electric guitar
# detexted vocals:
# ['FamilyBand_Again_STEM_09.wav', 'FamilyBand_Again_STEM_02.wav']
# (513, 11559)
# (513, 11559)
# (513, 11559)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/FamilyBand_Again.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\Grants_PunchDrunk_METADATA.yaml
# song: Grants_PunchDrunk
# stem: Grants_PunchDrunk_STEM_09.wav  piano
# stem: Grants_PunchDrunk_STEM_07.wav  male rapper
# this is vocal!
# stem: Grants_PunchDrunk_STEM_08.wav  sampler
# stem: Grants_PunchDrunk_STEM_04.wav  male rapper
# this is vocal!
# stem: Grants_PunchDrunk_STEM_03.wav  male rapper
# this is vocal!
# stem: Grants_PunchDrunk_STEM_02.wav bass electric bass
# stem: Grants_PunchDrunk_STEM_06.wav  fx/processed sound
# stem: Grants_PunchDrunk_STEM_10.wav  fx/processed sound
# stem: Grants_PunchDrunk_STEM_01.wav  sampler
# stem: Grants_PunchDrunk_STEM_05.wav  drum machine
# detexted vocals:
# ['Grants_PunchDrunk_STEM_07.wav', 'Grants_PunchDrunk_STEM_04.wav', 'Grants_PunchDrunk_STEM_03.wav']
# (513, 11749)
# (513, 11749)
# (513, 11749)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/Grants_PunchDrunk.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\Handel_TornamiAVagheggiar_METADATA.yaml
# song: Handel_TornamiAVagheggiar
# stem: Handel_TornamiAVagheggiar_STEM_02.wav melody piano
# stem: Handel_TornamiAVagheggiar_STEM_01.wav melody female singer
# this is vocal!
# detexted vocals:
# ['Handel_TornamiAVagheggiar_STEM_01.wav']
# (513, 12806)
# (513, 12806)
# (513, 12806)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/Handel_TornamiAVagheggiar.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\HeladoNegro_MitadDelMundo_METADATA.yaml
# song: HeladoNegro_MitadDelMundo
# stem: HeladoNegro_MitadDelMundo_STEM_09.wav  synthesizer
# stem: HeladoNegro_MitadDelMundo_STEM_07.wav  vibraphone
# stem: HeladoNegro_MitadDelMundo_STEM_08.wav melody male singer
# this is vocal!
# stem: HeladoNegro_MitadDelMundo_STEM_04.wav  drum machine
# stem: HeladoNegro_MitadDelMundo_STEM_03.wav  male singer
# this is vocal!
# stem: HeladoNegro_MitadDelMundo_STEM_02.wav bass synthesizer
# stem: HeladoNegro_MitadDelMundo_STEM_06.wav  synthesizer
# stem: HeladoNegro_MitadDelMundo_STEM_10.wav  tack piano
# stem: HeladoNegro_MitadDelMundo_STEM_01.wav  fx/processed sound
# stem: HeladoNegro_MitadDelMundo_STEM_05.wav  synthesizer
# detexted vocals:
# ['HeladoNegro_MitadDelMundo_STEM_08.wav', 'HeladoNegro_MitadDelMundo_STEM_03.wav']
# (513, 10443)
# (513, 10443)
# (513, 10443)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/HeladoNegro_MitadDelMundo.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\HezekiahJones_BorrowedHeart_METADATA.yaml
# song: HezekiahJones_BorrowedHeart
# stem: HezekiahJones_BorrowedHeart_STEM_11.wav  violin section
# stem: HezekiahJones_BorrowedHeart_STEM_09.wav  drum set
# stem: HezekiahJones_BorrowedHeart_STEM_07.wav  cymbal
# stem: HezekiahJones_BorrowedHeart_STEM_08.wav  auxiliary percussion
# stem: HezekiahJones_BorrowedHeart_STEM_04.wav bass electric bass
# stem: HezekiahJones_BorrowedHeart_STEM_03.wav  banjo
# stem: HezekiahJones_BorrowedHeart_STEM_02.wav melody vocalists
# this is vocal!
# stem: HezekiahJones_BorrowedHeart_STEM_06.wav  vocalists
# this is vocal!
# stem: HezekiahJones_BorrowedHeart_STEM_10.wav melody male singer
# this is vocal!
# stem: HezekiahJones_BorrowedHeart_STEM_01.wav  acoustic guitar
# stem: HezekiahJones_BorrowedHeart_STEM_12.wav melody lap steel guitar
# stem: HezekiahJones_BorrowedHeart_STEM_05.wav  vibraphone
# detexted vocals:
# ['HezekiahJones_BorrowedHeart_STEM_02.wav', 'HezekiahJones_BorrowedHeart_STEM_06.wav', 'HezekiahJones_BorrowedHeart_STEM_10.wav']
# (513, 13872)
# (513, 13872)
# (513, 13872)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/HezekiahJones_BorrowedHeart.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\HopAlong_SisterCities_METADATA.yaml
# song: HopAlong_SisterCities
# stem: HopAlong_SisterCities_STEM_07.wav melody female singer
# this is vocal!
# stem: HopAlong_SisterCities_STEM_08.wav  distorted electric guitar
# stem: HopAlong_SisterCities_STEM_04.wav  drum set
# stem: HopAlong_SisterCities_STEM_03.wav  vocalists
# this is vocal!
# stem: HopAlong_SisterCities_STEM_02.wav bass electric bass
# stem: HopAlong_SisterCities_STEM_06.wav melody distorted electric guitar
# stem: HopAlong_SisterCities_STEM_01.wav  acoustic guitar
# stem: HopAlong_SisterCities_STEM_05.wav  synthesizer
# detexted vocals:
# ['HopAlong_SisterCities_STEM_07.wav', 'HopAlong_SisterCities_STEM_03.wav']
# (513, 16275)
# (513, 16275)
# (513, 16275)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/HopAlong_SisterCities.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\InvisibleFamiliars_DisturbingWildlife_METADATA.yaml
# song: InvisibleFamiliars_DisturbingWildlife
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_09.wav melody male singer
# this is vocal!
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_07.wav melody vocalists
# this is vocal!
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_08.wav melody vocalists
# this is vocal!
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_04.wav  drum set
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_03.wav melody trumpet section
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_02.wav  claps
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_06.wav  shaker
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_10.wav melody tack piano
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_01.wav bass electric bass
# stem: InvisibleFamiliars_DisturbingWildlife_STEM_05.wav  clean electric guitar
# detexted vocals:
# ['InvisibleFamiliars_DisturbingWildlife_STEM_09.wav', 'InvisibleFamiliars_DisturbingWildlife_STEM_07.wav', 'InvisibleFamiliars_DisturbingWildlife_STEM_08.wav']
# (513, 12558)
# (513, 12558)
# (513, 12558)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/InvisibleFamiliars_DisturbingWildlife.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\JoelHelander_Definition_METADATA.yaml
# song: JoelHelander_Definition
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\JoelHelander_ExcessiveResistancetoChange_METADATA.yaml
# song: JoelHelander_ExcessiveResistancetoChange
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\JoelHelander_IntheAtticBedroom_METADATA.yaml
# song: JoelHelander_IntheAtticBedroom
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\KarimDouaidy_Hopscotch_METADATA.yaml
# song: KarimDouaidy_Hopscotch
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\KarimDouaidy_Yatora_METADATA.yaml
# song: KarimDouaidy_Yatora
# Instrumental track. Skipped.
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\LizNelson_Coldwar_METADATA.yaml
# song: LizNelson_Coldwar
# stem: LizNelson_Coldwar_STEM_02.wav melody female singer
# this is vocal!
# stem: LizNelson_Coldwar_STEM_01.wav melody acoustic guitar
# detexted vocals:
# ['LizNelson_Coldwar_STEM_02.wav']
# (513, 9762)
# (513, 9762)
# (513, 9762)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/LizNelson_Coldwar.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\LizNelson_ImComingHome_METADATA.yaml
# song: LizNelson_ImComingHome
# stem: LizNelson_ImComingHome_STEM_04.wav melody female singer
# this is vocal!
# stem: LizNelson_ImComingHome_STEM_03.wav  female singer
# this is vocal!
# stem: LizNelson_ImComingHome_STEM_02.wav  female singer
# this is vocal!
# stem: LizNelson_ImComingHome_STEM_01.wav melody female singer
# this is vocal!
# detexted vocals:
# ['LizNelson_ImComingHome_STEM_04.wav', 'LizNelson_ImComingHome_STEM_03.wav', 'LizNelson_ImComingHome_STEM_02.wav', 'LizNelson_ImComingHome_STEM_01.wav']
# empty vocal or inst data ... skip!
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\LizNelson_Rainfall_METADATA.yaml
# song: LizNelson_Rainfall
# stem: LizNelson_Rainfall_STEM_04.wav  acoustic guitar
# stem: LizNelson_Rainfall_STEM_03.wav  female singer
# this is vocal!
# stem: LizNelson_Rainfall_STEM_02.wav  female singer
# this is vocal!
# stem: LizNelson_Rainfall_STEM_01.wav melody female singer
# this is vocal!
# stem: LizNelson_Rainfall_STEM_05.wav  clean electric guitar
# detexted vocals:
# ['LizNelson_Rainfall_STEM_03.wav', 'LizNelson_Rainfall_STEM_02.wav', 'LizNelson_Rainfall_STEM_01.wav']
# (513, 16361)
# (513, 16361)
# (513, 16361)
# Saving: E:/Datasets/sound/MedleyDB/spectrograms/LizNelson_Rainfall.npz
# ******************************************************************************************************************************************************
# YAML file: E:\Datasets\sound\MedleyDB\Metadata\Lushlife_ToynbeeSuite_METADATA.yaml
# song: Lushlife_ToynbeeSuite
# stem: Lushlife_ToynbeeSuite_STEM_11.wav  clean electric guitar
# stem: Lushlife_ToynbeeSuite_STEM_13.wav  horn section
# stem: Lushlife_ToynbeeSuite_STEM_09.wav  glockenspiel
# stem: Lushlife_ToynbeeSuite_STEM_07.wav  drum set
# stem: Lushlife_ToynbeeSuite_STEM_21.wav  synthesizer
# stem: Lushlife_ToynbeeSuite_STEM_04.wav melody clarinet
# stem: Lushlife_ToynbeeSuite_STEM_02.wav  drum machine
# stem: Lushlife_ToynbeeSuite_STEM_06.wav  drum machine
# stem: Lushlife_ToynbeeSuite_STEM_19.wav  synthesizer
# stem: Lushlife_ToynbeeSuite_STEM_18.wav  male rapper
# this is vocal!
# stem: Lushlife_ToynbeeSuite_STEM_10.wav  clean electric guitar
# stem: Lushlife_ToynbeeSuite_STEM_15.wav  fx/processed sound
# stem: Lushlife_ToynbeeSuite_STEM_12.wav  clean electric guitar
# stem: Lushlife_ToynbeeSuite_STEM_05.wav  synthesizer
# stem: Lushlife_ToynbeeSuite_STEM_20.wav  fx/processed sound
# stem: Lushlife_ToynbeeSuite_STEM_08.wav bass electric bass
# stem: Lushlife_ToynbeeSuite_STEM_03.wav  claps
# stem: Lushlife_ToynbeeSuite_STEM_26.wav  male rapper
# this is vocal!
# stem: Lushlife_ToynbeeSuite_STEM_16.wav bass synthesizer
# stem: Lushlife_ToynbeeSuite_STEM_17.wav  male rapper
# this is vocal!
# stem: Lushlife_ToynbeeSuite_STEM_22.wav  drum machine
# stem: Lushlife_ToynbeeSuite_STEM_01.wav  brass section
# stem: Lushlife_ToynbeeSuite_STEM_24.wav  string section
# stem: Lushlife_ToynbeeSuite_STEM_23.wav  piano
# stem: Lushlife_ToynbeeSuite_STEM_14.wav  trumpet section
# stem: Lushlife_ToynbeeSuite_STEM_25.wav  scratches
# detexted vocals:
# ['Lushlife_ToynbeeSuite_STEM_18.wav', 'Lushlife_ToynbeeSuite_STEM_26.wav', 'Lushlife_ToynbeeSuite_STEM_17.wav']
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-571ae700836c> in <module>()
#      45     # 各音源をまとめる
#      46     audio_inst = sum([load(os.path.join(stem_path, f), sr=None, mono=True)[0]
# ---> 47                       for f in stem_inst])
#      48     audio_vocal = sum([load(os.path.join(stem_path, f), sr=None, mono=True)[0]
#      49                       for f in stem_vocal])
#
# <ipython-input-5-571ae700836c> in <listcomp>(.0)
#      45     # 各音源をまとめる
#      46     audio_inst = sum([load(os.path.join(stem_path, f), sr=None, mono=True)[0]
# ---> 47                       for f in stem_inst])
#      48     audio_vocal = sum([load(os.path.join(stem_path, f), sr=None, mono=True)[0]
#      49                       for f in stem_vocal])
#
# ~\AppData\Roaming\Python\Python35\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     157
#     158     if y:
# --> 159         y = np.concatenate(y)
#     160
#     161         if n_channels > 1:
#
# MemoryError:
